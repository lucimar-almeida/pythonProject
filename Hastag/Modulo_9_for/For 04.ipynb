# %% [markdown]
# # Enumerate
#
# ### Estrutura:
#
# O enumerate permite que você percorra uma lista e ao mesmo tempo tenha em uma variável o índice daquele item.
#
# - for normalmente

# %% [raw]
# for item in lista:
#     resto do código

# %%
funcionarios = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']

for funcionario in funcionarios:
    print(funcionario)
# Out:
# Maria
# José
# Antônio
# João
# Francisco
# Ana
# Luiz
# Paulo
# Carlos
# Manoel
# Pedro
# Francisca
# Marcos
# Raimundo
# Sebastião
# Antônia
# Marcelo
# Jorge
# Márcia
# Geraldo
# Adriana
# Sandra
# Luis

# %% [raw]
# for i, item in enumerate(lista):
#     resto do código

# %%
funcionarios = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']
for i, funcionario in enumerate(funcionarios):
    print(f'O {i} é o número do funcionario {funcionario}')
# Out:
# O 0 é o número do funcionario Maria
# O 1 é o número do funcionario José
# O 2 é o número do funcionario Antônio
# O 3 é o número do funcionario João
# O 4 é o número do funcionario Francisco
# O 5 é o número do funcionario Ana
# O 6 é o número do funcionario Luiz
# O 7 é o número do funcionario Paulo
# O 8 é o número do funcionario Carlos
# O 9 é o número do funcionario Manoel
# O 10 é o número do funcionario Pedro
# O 11 é o número do funcionario Francisca
# O 12 é o número do funcionario Marcos
# O 13 é o número do funcionario Raimundo
# O 14 é o número do funcionario Sebastião
# O 15 é o número do funcionario Antônia
# O 16 é o número do funcionario Marcelo
# O 17 é o número do funcionario Jorge
# O 18 é o número do funcionario Márcia
# O 19 é o número do funcionario Geraldo
# O 20 é o número do funcionario Adriana
# O 21 é o número do funcionario Sandra
# O 22 é o número do funcionario Luis

# %% [markdown]
# ### Exemplo Prático
#
# Vamos pegar um exemplo de nível mínimo de estoque. Em uma fábrica você tem vários produtos e não pode deixar que os produtos fiquem em falta. Para isso, foi definido uma quantidade mínima de estoque que os produtos precisam ter:
#
# Identifique quais produtos estão abaixo do nível mínimo de estoque.

# %%
#from ADS.mercado import produto


estoque = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
produtos = ['coca', 'pepsi', 'guarana', 'skol', 'brahma', 'agua', 'del valle', 'dolly', 'red bull', 'cachaça', 'vinho tinto', 'vodka', 'vinho branco', 'tequila', 'champagne', 'gin', 'guaracamp', 'matte', 'leite de castanha', 'leite', 'jurupinga', 'sprite', 'fanta']
nivel_minimo = 50

for i, produto in enumerate(produtos):
    if estoque[i] < nivel_minimo:
        print(f'O {produtos[i]} esta abaixo do estoque minimo que é de {nivel_minimo}.')
# Out:
# O dolly esta abaixo do estoque minimo que é de 50.
# O red bull esta abaixo do estoque minimo que é de 50.
